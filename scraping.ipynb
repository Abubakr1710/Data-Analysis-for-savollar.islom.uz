# %% [markdown]
# # <h1><center>WEB SCRAPING</center></h1>

# %% [markdown]
# <h3><center>website: <a href="https://savollar.islom.uz/">savollar.islom.uz</a></center></h3>

# %%
#importing libraries for scraping
from bs4 import BeautifulSoup #library to parse HTML and XML documents
import requests #library to handle requests
import pandas as pd #library for working with dataframes

# %%
url = "https://savollar.islom.uz/" # url of the website

# %%
response = requests.get(url) # get the response from the website
response.status_code # check the status code of the response --> 200 means OK
# Out:
# 200

# %%
#creating dataframe of the link for all page
df = pd.DataFrame(columns=['link'])

# %%
for i in range(0, 7208):
  df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# Out:
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# ...
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)
# /tmp/ipykernel_4215/4182609874.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'link': 'https://savollar.islom.uz/savol/'+str(i+1)}, ignore_index=True)

# %%
df
# Out:
#                                       link
# 0        https://savollar.islom.uz/savol/1
# 1        https://savollar.islom.uz/savol/2
# 2        https://savollar.islom.uz/savol/3
# 3        https://savollar.islom.uz/savol/4
# 4        https://savollar.islom.uz/savol/5
# ...                                    ...
# 7203  https://savollar.islom.uz/savol/7204
# 7204  https://savollar.islom.uz/savol/7205
# 7205  https://savollar.islom.uz/savol/7206
# 7206  https://savollar.islom.uz/savol/7207
# 7207  https://savollar.islom.uz/savol/7208
#
# [7208 rows x 1 columns]
